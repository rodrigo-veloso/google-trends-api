# %%
from pytrends.request import TrendReq

# %%
pytrends = TrendReq(hl='pt-BR', tz=360)

# %%
keyword = ['Boticário','Dafiti','Mercado Livre']

# %%
pytrends.build_payload(kw_list = keyword, cat=0, timeframe='today 5-y', geo='BR', gprop='')

# %%
data = pytrends.interest_over_time()

# %%
data.plot()

# %%
pytrends.interest_by_region(resolution='CITY', inc_low_vol=False, inc_geo_code=False)
# Out:
#                      Boticário  Dafiti  Mercado Livre
# geoName
# Acre                         5       8             87
# Alagoas                      4      11             85
# Amapá                        6       6             88
# Amazonas                     6       5             89
# Bahia                        3       9             88
# Ceará                        5       8             87
# Distrito Federal             3      10             87
# Espírito Santo               2       8             90
# Goiás                        3       8             89
# Maranhão                     4      10             86
# Mato Grosso                  2       8             90
# Mato Grosso do Sul           2       7             91
# Minas Gerais                 2       9             89
# Paraná                       2       9             89
# Paraíba                      4      14             82
# Pará                         5       6             89
# Pernambuco                   4      11             85
# Piauí                        4      13             83
# Rio Grande do Norte          4      13             83
# Rio Grande do Sul            2       9             89
# Rio de Janeiro               2       8             90
# Rondônia                     4       8             88
# Roraima                      5       6             89
# Santa Catarina               2       8             90
# Sergipe                      4      11             85
# São Paulo                    2      10             88
# Tocantins                    3      12             85
